# %%
import matplotlib.pyplot as plt
import numpy as np

K = np.array([[-100, 0,200],
       [0, -100,200],
       [0,0,1]]) 
extrinxleft = np.array([[0.707, 0.707,0,-3],
       [-0.707,0.707,0,-0.5],
       [0,0,1,3]])
extrinxright = np.array([[0.866,-0.5,0,-3],
       [0.5,0.866,0,-0.5],
       [0,0,1,3]])

pt1 = np.array([[2],
           [0],
           [0],
           [1]])
pt2 = np.array([[3],
           [0],
           [0],
           [1]])
pt3 = np.array([[3],
           [1],
           [0],
           [1]])
pt4 = np.array([[2],
           [1],
           [0],
           [1]])
pt5 = np.array([[2],
           [0],
           [1],
           [1]])
pt6 = np.array([[3],
           [0],
           [1],
           [1]])
pt7 = np.array([[3],
           [1],
           [1],
           [1]])
pt8 = np.array([[2],
           [1],
           [1],
           [1]])
pt9 = np.array([[2.5],
           [0.5],
           [2],
           [1]])
L = np.matmul(K, extrinxleft);
R = np.matmul(K, extrinxright);
pixel1L = np.matmul(L, pt1);
pixel1L = pixel1L/pixel1L[2];
pixel2L = np.matmul(L, pt2);
pixel2L = pixel2L/pixel2L[2];
pixel3L = np.matmul(L, pt3);
pixel3L = pixel3L/pixel3L[2];
pixel4L = np.matmul(L, pt4);
pixel4L = pixel4L/pixel4L[2];
pixel5L = np.matmul(L, pt5);
pixel5L = pixel5L/pixel5L[2];
pixel6L = np.matmul(L, pt6);
pixel6L = pixel6L/pixel6L[2];
pixel7L = np.matmul(L, pt7);
pixel7L = pixel7L/pixel7L[2];
pixel8L = np.matmul(L, pt8);
pixel8L = pixel8L/pixel8L[2];
pixel9L = np.matmul(L, pt9);
pixel9L = pixel9L/pixel9L[2];
pixel1R = np.matmul(R, pt1);
pixel1R = pixel1R/pixel1R[2];
pixel2R = np.matmul(R, pt2);
pixel2R = pixel2R/pixel2R[2];
pixel3R = np.matmul(R, pt3);
pixel3R = pixel3R/pixel3R[2];
pixel4R = np.matmul(R, pt4);
pixel4R = pixel4R/pixel4R[2];
pixel5R = np.matmul(R, pt5);
pixel5R = pixel5R/pixel5R[2];
pixel6R = np.matmul(R, pt6);
pixel6R = pixel6R/pixel6R[2];
pixel7R = np.matmul(R, pt7);
pixel7R = pixel7R/pixel7R[2];
pixel8R = np.matmul(R, pt8);
pixel8R = pixel8R/pixel8R[2];
pixel9R = np.matmul(R, pt9);
pixel9R = pixel9R/pixel9R[2];

pixel1L = np.delete(pixel1L,2,0);
pixel2L = np.delete(pixel2L,2,0);
pixel3L = np.delete(pixel3L,2,0);
pixel4L = np.delete(pixel4L,2,0);
pixel5L = np.delete(pixel5L,2,0);
pixel6L = np.delete(pixel6L,2,0);
pixel7L = np.delete(pixel7L,2,0);
pixel8L = np.delete(pixel8L,2,0);
pixel9L = np.delete(pixel9L,2,0);
pixel1R = np.delete(pixel1R,2,0);
pixel2R = np.delete(pixel2R,2,0);
pixel3R = np.delete(pixel3R,2,0);
pixel4R = np.delete(pixel4R,2,0);
pixel5R = np.delete(pixel5R,2,0);
pixel6R = np.delete(pixel6R,2,0);
pixel7R = np.delete(pixel7R,2,0);
pixel8R = np.delete(pixel8R,2,0);
pixel9R = np.delete(pixel9R,2,0);

CameraXL = [pixel1L[0,0],pixel2L[0,0],pixel3L[0,0],pixel4L[0,0],pixel1L[0,0],pixel5L[0,0],pixel8L[0,0],pixel4L[0,0],pixel8L[0,0],pixel7L[0,0],pixel3L[0,0],pixel7L[0,0],pixel6L[0,0],pixel2L[0,0],pixel6L[0,0],pixel5L[0,0]];
CameraYL = [pixel1L[1,0],pixel2L[1,0],pixel3L[1,0],pixel4L[1,0],pixel1L[1,0],pixel5L[1,0],pixel8L[1,0],pixel4L[1,0],pixel8L[1,0],pixel7L[1,0],pixel3L[1,0],pixel7L[1,0],pixel6L[1,0],pixel2L[1,0],pixel6L[1,0],pixel5L[1,0]];
CameraXR = [pixel1R[0,0],pixel2R[0,0],pixel3R[0,0],pixel4R[0,0],pixel1R[0,0],pixel5R[0,0],pixel6R[0,0],pixel2R[0,0],pixel3R[0,0],pixel7R[0,0],pixel6R[0,0],pixel7R[0,0],pixel8R[0,0],pixel4R[0,0],pixel8R[0,0],pixel5R[0,0]];
CameraYR = [pixel1R[1,0],pixel2R[1,0],pixel3R[1,0],pixel4R[1,0],pixel1R[1,0],pixel5R[1,0],pixel6R[1,0],pixel2R[1,0],pixel3R[1,0],pixel7R[1,0],pixel6R[1,0],pixel7R[1,0],pixel8R[1,0],pixel4R[1,0],pixel8R[1,0],pixel5R[1,0]];

plt.title(label="Left");
plt.plot(CameraXL,CameraYL);
plot2 = plt.figure(2);
plt.plot(CameraXR,CameraYR);
plt.title(label="Right")

plt.show()

# %%
#Problem 1
import matplotlib.pyplot as plt
kin = np.linalg.inv(K)
right1 = np.concatenate((np.transpose(pixel1R), np.transpose(pixel2R),np.transpose(pixel3R),np.transpose(pixel4R),np.transpose(pixel5R),np.transpose(pixel6R),np.transpose(pixel7R),np.transpose(pixel8R),np.transpose(pixel9R)));
left1 = np.concatenate((np.transpose(pixel1L), np.transpose(pixel2L),np.transpose(pixel3L),np.transpose(pixel4L),np.transpose(pixel5L),np.transpose(pixel6L),np.transpose(pixel7L),np.transpose(pixel8L),np.transpose(pixel9L)));
new_column = [[1], [1],[1],[1],[1],[1],[1],[1],[1]];
right1 = np.append(right1, new_column, axis=1);
left1 = np.append(left1, new_column, axis=1);
rightray = np.matmul(kin,np.transpose(right1));
leftray = np.matmul(kin,np.transpose(left1));
Trw = np.array([[0.866,-0.5,0,-3],
       [0.5,0.866,0,-0.5],
       [0,0,1,3],
       [0,0,0,1]]);
Tlw = np.array([[0.707, 0.707,0,-3],
       [-0.707,0.707,0,-0.5],
       [0,0,1,3],
       [0,0,0,1]]);
Twr = np.linalg.inv(Trw);
Twl = np.linalg.inv(Tlw);

Tlr = np.matmul(Tlw,Twr);

Rlr = Tlr[0:3,0:3];
tlr = np.array([[Tlr[0,3]],[Tlr[1,3]],[Tlr[2,3]]])
leftray1 = leftray[0:3,0];
leftray2 = leftray[0:3,1];
leftray3 = leftray[0:3,2];
leftray4 = leftray[0:3,3];
leftray5 = leftray[0:3,4];
leftray6 = leftray[0:3,5];
leftray7 = leftray[0:3,6];
leftray8 = leftray[0:3,7];
leftray9 = leftray[0:3,8];
rightray1 = rightray[0:3,0];
rightray2 = rightray[0:3,1];
rightray3 = rightray[0:3,2];
rightray4 = rightray[0:3,3];
rightray5 = rightray[0:3,4];
rightray6 = rightray[0:3,5];
rightray7 = rightray[0:3,6];
rightray8 = rightray[0:3,7];
rightray9 = rightray[0:3,8];

#point 1
q = np.cross(leftray1,np.matmul(Rlr,rightray1));
q = q / np.linalg.norm(q);
A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray1 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
reconpts = np.transpose(three_d_point);
#point2
q = np.cross(leftray2,np.matmul(Rlr,rightray2));
q = q / np.linalg.norm(q);
A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray2 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point3
q = np.cross(leftray3,np.matmul(Rlr,rightray3));
q = q / np.linalg.norm(q);
A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray3 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point4
q = np.cross(leftray4,np.matmul(Rlr,rightray4));
q = q / np.linalg.norm(q);
A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray4 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point5
q = np.cross(leftray5,np.matmul(Rlr,rightray5));
q = q / np.linalg.norm(q);
A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray5 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point6
q = np.cross(leftray6,np.matmul(Rlr,rightray6));
q = q / np.linalg.norm(q);
A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray6 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point7
q = np.cross(leftray7,np.matmul(Rlr,rightray7));
q = q / np.linalg.norm(q);
A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray7 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point8
q = np.cross(leftray8,np.matmul(Rlr,rightray8));
q = q / np.linalg.norm(q);
A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray8 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point9
q = np.cross(leftray9,np.matmul(Rlr,rightray9));
q = q / np.linalg.norm(q);
A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray9 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
reconpts = np.delete(reconpts, 3, 1);
print(reconpts)
X = [reconpts.item(0),reconpts.item(3),reconpts.item(6),reconpts.item(9),reconpts.item(0),reconpts.item(12),reconpts.item(15),reconpts.item(3),reconpts.item(15),reconpts.item(18),reconpts.item(6),reconpts.item(18),reconpts.item(21),reconpts.item(9),reconpts.item(21),reconpts.item(12)]
Y = [reconpts.item(1),reconpts.item(4),reconpts.item(7),reconpts.item(10),reconpts.item(1),reconpts.item(13),reconpts.item(16),reconpts.item(4),reconpts.item(16),reconpts.item(19),reconpts.item(7),reconpts.item(19),reconpts.item(22),reconpts.item(10),reconpts.item(22),reconpts.item(13)]
Z = [reconpts.item(2),reconpts.item(5),reconpts.item(8),reconpts.item(11),reconpts.item(2),reconpts.item(14),reconpts.item(17),reconpts.item(5),reconpts.item(17),reconpts.item(20),reconpts.item(8),reconpts.item(20),reconpts.item(23),reconpts.item(11),reconpts.item(23),reconpts.item(14)]
ax = plt.axes(projection ='3d')
ax.plot3D(X, Y, Z, 'green')
# Out:
# [[ 2.00000000e+00 -6.66133815e-16 -4.44089210e-16]
#  [ 3.00000000e+00  3.33066907e-16 -4.44089210e-16]
#  [ 3.00000000e+00  1.00000000e+00 -1.77635684e-15]
#  [ 2.00000000e+00  1.00000000e+00  0.00000000e+00]
#  [ 2.00000000e+00 -8.88178420e-16  1.00000000e+00]
#  [ 3.00000000e+00  4.44089210e-16  1.00000000e+00]
#  [ 3.00000000e+00  1.00000000e+00  1.00000000e+00]
#  [ 2.00000000e+00  1.00000000e+00  1.00000000e+00]
#  [ 2.50000000e+00  5.00000000e-01  2.00000000e+00]]

# %%
#Only Corresponding points
#Problem 3
Left = np.array([[pixel1L.item(0),pixel1L.item(1),1]]);
Right = np.array([[pixel1R.item(0),pixel1R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = merge;
#2
Left = np.array([[pixel2L.item(0),pixel2L.item(1),1]]);
Right = np.array([[pixel2R.item(0),pixel2R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#3
Left = np.array([[pixel3L.item(0),pixel3L.item(1),1]]);
Right = np.array([[pixel3R.item(0),pixel3R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#4
Left = np.array([[pixel4L.item(0),pixel4L.item(1),1]]);
Right = np.array([[pixel4R.item(0),pixel4R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#5
Left = np.array([[pixel5L.item(0),pixel5L.item(1),1]]);
Right = np.array([[pixel5R.item(0),pixel5R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#6
Left = np.array([[pixel6L.item(0),pixel6L.item(1),1]]);
Right = np.array([[pixel6R.item(0),pixel6R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#7
Left = np.array([[pixel7L.item(0),pixel7L.item(1),1]]);
Right = np.array([[pixel7R.item(0),pixel7R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#8
Left = np.array([[pixel8L.item(0),pixel8L.item(1),1]]);
Right = np.array([[pixel8R.item(0),pixel8R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#9
Left = np.array([[pixel9L.item(0),pixel9L.item(1),1]]);
Right = np.array([[pixel9R.item(0),pixel9R.item(1),1]]);
tt = np.matmul(np.transpose(Left),Right)
merge = np.array([[tt.item(0),tt.item(1),tt.item(2),tt.item(3),tt.item(4),tt.item(5),tt.item(6),tt.item(7),tt.item(8)]]);
A = np.vstack((A,merge))
#SVD
u, s, vh = np.linalg.svd(A, full_matrices=True)
vh = np.transpose(vh)
lastcol = np.array([[vh[0,8]],[vh[1,8]],[vh[2,8]],[vh[3,8]],[vh[4,8]],[vh[5,8]],[vh[6,8]],[vh[7,8]],[vh[8,8]]]);
#F
F = np.array([[lastcol.item(0),lastcol.item(1),lastcol.item(2)],
              [lastcol.item(3),lastcol.item(4),lastcol.item(5)],
              [lastcol.item(6),lastcol.item(7),lastcol.item(8)]]);

ktemp = np.identity(3);
u, s, vh = np.linalg.svd(np.transpose(F), full_matrices=True);
vh = np.transpose(vh);
lastcol = np.array([[vh[0,2]],[vh[1,2]],[vh[2,2]]])
epipole = lastcol;
e1 = epipole.item(0);
e2 = epipole.item(1);
e3 = epipole.item(2);
ecross = np.array([[0,-e3,e2],
                   [e3,0,-e1],
                   [-e2,e1,0]]);
J = np.matmul(ecross,F);
new_column = [[e1], [e2],[e3]];
cameramatrix = np.append(J, new_column, axis=1);
#Reconstruct
Rlr = np.array([[cameramatrix[0,0],cameramatrix[0,1],cameramatrix[0,2]],
              [cameramatrix[1,0],cameramatrix[1,1],cameramatrix[1,2]],
              [cameramatrix[2,0],cameramatrix[2,1],cameramatrix[2,2]]]);
tlr = np.array([[cameramatrix[0,3]],
                [cameramatrix[1,3]],
                [cameramatrix[2,3]]]);

rightray_noK = np.transpose(right1);
leftray_nok = np.transpose(left1);

Rlr = Rlr;
tlr = tlr
Twl = np.identity(4);

leftray1 = leftray_nok[0:3,0];
leftray2 = leftray_nok[0:3,1];
leftray3 = leftray_nok[0:3,2];
leftray4 = leftray_nok[0:3,3];
leftray5 = leftray_nok[0:3,4];
leftray6 = leftray_nok[0:3,5];
leftray7 = leftray_nok[0:3,6];
leftray8 = leftray_nok[0:3,7];
leftray9 = leftray_nok[0:3,8];
rightray1 = rightray_noK[0:3,0];
rightray2 = rightray_noK[0:3,1];
rightray3 = rightray_noK[0:3,2];
rightray4 = rightray_noK[0:3,3];
rightray5 = rightray_noK[0:3,4];
rightray6 = rightray_noK[0:3,5];
rightray7 = rightray_noK[0:3,6];
rightray8 = rightray_noK[0:3,7];
rightray9 = rightray_noK[0:3,8];
#point 1
q = np.cross(leftray1,np.matmul(Rlr,rightray1));
q = q / np.linalg.norm(q);
A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray1 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
reconpts = np.transpose(three_d_point);
#point2
q = np.cross(leftray2,np.matmul(Rlr,rightray2));
q = q / np.linalg.norm(q);
A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray2 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point3
q = np.cross(leftray3,np.matmul(Rlr,rightray3));
q = q / np.linalg.norm(q);
A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray3 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point4
q = np.cross(leftray4,np.matmul(Rlr,rightray4));
q = q / np.linalg.norm(q);
A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0]; 
b = solveit[1];
c = solveit[2];
output = a*leftray4 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point5
q = np.cross(leftray5,np.matmul(Rlr,rightray5));
q = q / np.linalg.norm(q);
A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray5 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point6
q = np.cross(leftray6,np.matmul(Rlr,rightray6));
q = q / np.linalg.norm(q);
A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray6 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point7
q = np.cross(leftray7,np.matmul(Rlr,rightray7));
q = q / np.linalg.norm(q);
A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray7 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point8
q = np.cross(leftray8,np.matmul(Rlr,rightray8));
q = q / np.linalg.norm(q);
A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray8 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
#point9
q = np.cross(leftray9,np.matmul(Rlr,rightray9));
q = q / np.linalg.norm(q);
A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
A = np.transpose(A)
solveit = np.matmul(np.linalg.inv(A),tlr);
a = solveit[0];
b = solveit[1];
c = solveit[2];
output = a*leftray9 + c*0.5*q;
output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
three_d_point = np.matmul(Twl,output);
three_d_point = np.transpose(three_d_point)
reconpts = np.vstack((reconpts,three_d_point));
reconpts = np.delete(reconpts, 3, 1);
#plot
print(reconpts)

X = [reconpts[5,0],reconpts[6,0],reconpts[7,0],reconpts[4,0],reconpts[5,0],reconpts[1,0],reconpts[2,0],reconpts[6,0],reconpts[2,0],reconpts[3,0],reconpts[7,0],reconpts[3,0],reconpts[0,0],reconpts[4,0],reconpts[0,0],reconpts[1,0]]
Y = [reconpts[5,1],reconpts[6,1],reconpts[7,1],reconpts[4,1],reconpts[5,1],reconpts[1,1],reconpts[2,1],reconpts[6,1],reconpts[2,1],reconpts[3,1],reconpts[7,1],reconpts[3,1],reconpts[0,1],reconpts[4,1],reconpts[0,1],reconpts[1,1]]
Z = [reconpts[5,2],reconpts[6,2],reconpts[7,2],reconpts[4,2],reconpts[5,2],reconpts[1,2],reconpts[2,2],reconpts[6,2],reconpts[2,2],reconpts[3,2],reconpts[7,2],reconpts[3,2],reconpts[0,2],reconpts[4,2],reconpts[0,2],reconpts[1,2]]
ax = plt.axes(projection ='3d')
ax.plot3D(X, Y, Z, 'green')
# Out:
# [[-0.71896445 -0.75005071 -0.00284326]
#  [-0.63442443 -0.79508258 -0.00276679]
#  [-0.62428437 -0.80048388 -0.00303443]
#  [-0.71694278 -0.75112758 -0.00312666]
#  [-0.72310372 -0.74784584 -0.00301733]
#  [-0.65535631 -0.78393281 -0.00295239]
#  [-0.6489847  -0.78732677 -0.00317663]
#  [-0.72184855 -0.74851443 -0.00325194]
#  [-0.69604148 -0.76226107 -0.00319901]]

# %%
#K is known
#Problem 2
E = np.matmul(np.transpose(K),F);
E = np.matmul(E,K);
W = np.array([[0,-1,0],
              [1,0,0],
              [0,0,1]]);
Z = np.array([[0,1,0],
              [-1,0,0],
              [0,0,0]]);
U, S, VH = np.linalg.svd(E, full_matrices=True);
VH = np.transpose(VH);
S1 = np.matmul(-U,Z);
S1 = np.matmul(S1,np.transpose(U));
S2 = np.matmul(U,Z);
S2 = np.matmul(S2,np.transpose(U));
R1 = np.matmul(U,np.transpose(W));
R1 = np.matmul(R1,np.transpose(VH));
R2 = np.matmul(U,W);
R2 = np.matmul(R2,np.transpose(VH));

leftray1 = leftray[0:3,0];
leftray2 = leftray[0:3,1];
leftray3 = leftray[0:3,2];
leftray4 = leftray[0:3,3];
leftray5 = leftray[0:3,4];
leftray6 = leftray[0:3,5];
leftray7 = leftray[0:3,6];
leftray8 = leftray[0:3,7];
leftray9 = leftray[0:3,8];
rightray1 = rightray[0:3,0];
rightray2 = rightray[0:3,1];
rightray3 = rightray[0:3,2];
rightray4 = rightray[0:3,3];
rightray5 = rightray[0:3,4];
rightray6 = rightray[0:3,5];
rightray7 = rightray[0:3,6];
rightray8 = rightray[0:3,7];
rightray9 = rightray[0:3,8];

foundit = 0;

#case1
if not foundit:
  S = S1;
  Rlr = R1;
  tlr = np.array([[S[2,1], S[0,2],-S[0,1]]]);
  tlr = np.transpose(tlr);
  #point 1
  q = np.cross(leftray1,np.matmul(Rlr,rightray1));
  q = q / np.linalg.norm(q);
  A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray1 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  reconpts = np.transpose(three_d_point);
  #point2
  q = np.cross(leftray2,np.matmul(Rlr,rightray2));
  q = q / np.linalg.norm(q);
  A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
  A = np.transpose(A);
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray2 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point3
  q = np.cross(leftray3,np.matmul(Rlr,rightray3));
  q = q / np.linalg.norm(q);
  A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray3 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point4
  q = np.cross(leftray4,np.matmul(Rlr,rightray4));
  q = q / np.linalg.norm(q);
  A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray4 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point5
  q = np.cross(leftray5,np.matmul(Rlr,rightray5));
  q = q / np.linalg.norm(q);
  A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray5 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point6
  q = np.cross(leftray6,np.matmul(Rlr,rightray6));
  q = q / np.linalg.norm(q);
  A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray6 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point7
  q = np.cross(leftray7,np.matmul(Rlr,rightray7));
  q = q / np.linalg.norm(q);
  A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray7 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point8
  q = np.cross(leftray8,np.matmul(Rlr,rightray8));
  q = q / np.linalg.norm(q);
  A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray8 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point9
  q = np.cross(leftray9,np.matmul(Rlr,rightray9));
  q = q / np.linalg.norm(q);
  A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  Twl = np.identity(4);
  output = a*leftray9 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  reconpts = -reconpts;
  reconpts = np.delete(reconpts, 3, 1);
  newreconstruct = reconpts[:,2];
  if np.amin(newreconstruct) > 0:
    foundit = 1;

#case 2
if not foundit:
  S = S2;
  Rlr = R1;
  tlr = np.array([[S[2,1], S[0,2],-S[0,1]]]);
  tlr = np.transpose(tlr);
  #point 1
  q = np.cross(leftray1,np.matmul(Rlr,rightray1));
  q = q / np.linalg.norm(q);
  A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray1 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  reconpts = np.transpose(three_d_point);
  #point2
  q = np.cross(leftray2,np.matmul(Rlr,rightray2));
  q = q / np.linalg.norm(q);
  A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
  A = np.transpose(A);
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray2 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point3
  q = np.cross(leftray3,np.matmul(Rlr,rightray3));
  q = q / np.linalg.norm(q);
  A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray3 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point4
  q = np.cross(leftray4,np.matmul(Rlr,rightray4));
  q = q / np.linalg.norm(q);
  A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray4 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point5
  q = np.cross(leftray5,np.matmul(Rlr,rightray5));
  q = q / np.linalg.norm(q);
  A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray5 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point6
  q = np.cross(leftray6,np.matmul(Rlr,rightray6));
  q = q / np.linalg.norm(q);
  A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray6 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point7
  q = np.cross(leftray7,np.matmul(Rlr,rightray7));
  q = q / np.linalg.norm(q);
  A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray7 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point8
  q = np.cross(leftray8,np.matmul(Rlr,rightray8));
  q = q / np.linalg.norm(q);
  A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray8 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point9
  q = np.cross(leftray9,np.matmul(Rlr,rightray9));
  q = q / np.linalg.norm(q);
  A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  Twl = np.identity(4);
  output = a*leftray9 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  reconpts = -reconpts;
  reconpts = np.delete(reconpts, 3, 1);
  if np.amin(reconpts[0:8,2]) > 0:
    foundit = 1;

#case 3
if not foundit:
  S = S1;
  Rlr = R2;
  tlr = np.array([[S[2,1], S[0,2],-S[0,1]]]);
  tlr = np.transpose(tlr);
  #point 1
  q = np.cross(leftray1,np.matmul(Rlr,rightray1));
  q = q / np.linalg.norm(q);
  A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray1 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  reconpts = np.transpose(three_d_point);
  #point2
  q = np.cross(leftray2,np.matmul(Rlr,rightray2));
  q = q / np.linalg.norm(q);
  A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
  A = np.transpose(A);
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray2 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point3
  q = np.cross(leftray3,np.matmul(Rlr,rightray3));
  q = q / np.linalg.norm(q);
  A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray3 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point4
  q = np.cross(leftray4,np.matmul(Rlr,rightray4));
  q = q / np.linalg.norm(q);
  A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray4 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point5
  q = np.cross(leftray5,np.matmul(Rlr,rightray5));
  q = q / np.linalg.norm(q);
  A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray5 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point6
  q = np.cross(leftray6,np.matmul(Rlr,rightray6));
  q = q / np.linalg.norm(q);
  A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray6 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point7
  q = np.cross(leftray7,np.matmul(Rlr,rightray7));
  q = q / np.linalg.norm(q);
  A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray7 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point8
  q = np.cross(leftray8,np.matmul(Rlr,rightray8));
  q = q / np.linalg.norm(q);
  A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray8 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point9
  q = np.cross(leftray9,np.matmul(Rlr,rightray9));
  q = q / np.linalg.norm(q);
  A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  Twl = np.identity(4);
  output = a*leftray9 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  reconpts = -reconpts;
  reconpts = np.delete(reconpts, 3, 1);
  if np.amin(reconpts[0:8,2]) > 0:
    foundit = 1;
  print(reconpts)

#case 4
if not foundit:
  S = S2;
  Rlr = R2;
  tlr = np.array([[S[2,1], S[0,2],-S[0,1]]]);
  tlr = np.transpose(tlr);
  #point 1
  q = np.cross(leftray1,np.matmul(Rlr,rightray1));
  q = q / np.linalg.norm(q);
  A = np.array([leftray1,np.matmul(-Rlr,rightray1),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray1 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  reconpts = np.transpose(three_d_point);
  #point2
  q = np.cross(leftray2,np.matmul(Rlr,rightray2));
  q = q / np.linalg.norm(q);
  A = np.array([leftray2,np.matmul(-Rlr,rightray2),q]);
  A = np.transpose(A);
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray2 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point3
  q = np.cross(leftray3,np.matmul(Rlr,rightray3));
  q = q / np.linalg.norm(q);
  A = np.array([leftray3,np.matmul(-Rlr,rightray3),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray3 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point4
  q = np.cross(leftray4,np.matmul(Rlr,rightray4));
  q = q / np.linalg.norm(q);
  A = np.array([leftray4,np.matmul(-Rlr,rightray4),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray4 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point5
  q = np.cross(leftray5,np.matmul(Rlr,rightray5));
  q = q / np.linalg.norm(q);
  A = np.array([leftray5,np.matmul(-Rlr,rightray5),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray5 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point6
  q = np.cross(leftray6,np.matmul(Rlr,rightray6));
  q = q / np.linalg.norm(q);
  A = np.array([leftray6,np.matmul(-Rlr,rightray6),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray6 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point7
  q = np.cross(leftray7,np.matmul(Rlr,rightray7));
  q = q / np.linalg.norm(q);
  A = np.array([leftray7,np.matmul(-Rlr,rightray7),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray7 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point8
  q = np.cross(leftray8,np.matmul(Rlr,rightray8));
  q = q / np.linalg.norm(q);
  A = np.array([leftray8,np.matmul(-Rlr,rightray8),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  output = a*leftray8 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  #point9
  q = np.cross(leftray9,np.matmul(Rlr,rightray9));
  q = q / np.linalg.norm(q);
  A = np.array([leftray9,np.matmul(-Rlr,rightray9),q]);
  A = np.transpose(A)
  solveit = np.matmul(np.linalg.inv(A),tlr);
  a = solveit[0];
  b = solveit[1];
  c = solveit[2];
  Twl = np.identity(4);
  output = a*leftray9 + c*0.5*q;
  output = np.array([[output[0]],[output[1]],[output[2]],[1]]);
  three_d_point = np.matmul(Twl,output);
  three_d_point = np.transpose(three_d_point)
  reconpts = np.vstack((reconpts,three_d_point));
  reconpts = -reconpts;
  reconpts = np.delete(reconpts, 3, 1);
  if np.amin(reconpts[0:8,2]) > 0:
    foundit = 1;
  
#plot
X = [reconpts[7,0],reconpts[6,0],reconpts[5,0],reconpts[4,0],reconpts[7,0],reconpts[3,0],reconpts[2,0],reconpts[6,0],reconpts[2,0],reconpts[1,0],reconpts[5,0],reconpts[1,0],reconpts[0,0],reconpts[4,0],reconpts[0,0],reconpts[3,0]]
Y = [reconpts[7,1],reconpts[6,1],reconpts[5,1],reconpts[4,1],reconpts[7,1],reconpts[3,1],reconpts[2,1],reconpts[6,1],reconpts[2,1],reconpts[1,1],reconpts[5,1],reconpts[1,1],reconpts[0,1],reconpts[4,1],reconpts[0,1],reconpts[3,1]]
Z = [reconpts[7,2],reconpts[6,2],reconpts[5,2],reconpts[4,2],reconpts[7,2],reconpts[3,2],reconpts[2,2],reconpts[6,2],reconpts[2,2],reconpts[1,2],reconpts[5,2],reconpts[1,2],reconpts[0,2],reconpts[4,2],reconpts[0,2],reconpts[3,2]]
ax = plt.axes(projection ='3d')
ax.plot3D(X, Y, Z, 'green')
# Out:
# [[-0.42832017 -0.51688788  0.81017392]
#  [-0.23737682 -0.70783373  0.81018204]
#  [-0.04643828 -0.51688708  0.81015573]
#  [-0.23737646 -0.32594771  0.81014742]
#  [-0.42832004 -0.51688756  1.08023215]
#  [-0.23737668 -0.70783353  1.08024304]
#  [-0.04643791 -0.51688637  1.08020757]
#  [-0.23737642 -0.32594766  1.08019653]
#  [-0.23737644 -0.51688629  1.35027496]]
