# %%
##Brianna Solano
##Homeowrk 4

# %%
from PIL import Image
import math
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib
import numpy as np
from skimage import color
from skimage import io
import numpy as np
from PIL import Image, ImageFilter
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# First Octive

# %%
octive1 = Image.open("homework4.jpg").convert("L")
octive1arr = np.asarray(octive1)
plt.imshow(octive1arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive1_2 = octive1.filter(ImageFilter.GaussianBlur(radius = 5))
octive1_2arr = np.asarray(octive1_2)
plt.imshow(octive1_2arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive1_3 = octive1.filter(ImageFilter.GaussianBlur(radius = 6))
octive1_3arr = np.asarray(octive1_3)
plt.imshow(octive1_3arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive1_4 = octive1.filter(ImageFilter.GaussianBlur(radius = 7))
octive1_4arr = np.asarray(octive1_4)
plt.imshow(octive1_4arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive1_5 = octive1.filter(ImageFilter.GaussianBlur(radius = 8))
octive1_5arr = np.asarray(octive1_5)
plt.imshow(octive1_5arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
dog1_1 = octive1arr - octive1_2arr
plt.imshow(dog1_1, cmap='gray', vmin=0, vmax=255)
plt.show()
dog1_2 = octive1_2arr - octive1_3arr
plt.imshow(dog1_2, cmap='gray', vmin=0, vmax=255)
plt.show()
dog1_3 = octive1_3arr - octive1_4arr
plt.imshow(dog1_3, cmap='gray', vmin=0, vmax=255)
plt.show()
dog1_4 = octive1_4arr - octive1_5arr
plt.imshow(dog1_4, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Second Octive

# %%
octive2 = octive1.resize((800, 534))
octive2arr = np.asarray(octive2)
plt.imshow(octive2arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive2_2 = octive2.filter(ImageFilter.GaussianBlur(radius = 5))
octive2_2arr = np.asarray(octive2_2)
plt.imshow(octive2_2arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive2_3 = octive2.filter(ImageFilter.GaussianBlur(radius = 6))
octive2_3arr = np.asarray(octive2_3)
plt.imshow(octive2_3arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive2_4 = octive2.filter(ImageFilter.GaussianBlur(radius = 7))
octive2_4arr = np.asarray(octive2_4)
plt.imshow(octive2_4arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive2_5 = octive2.filter(ImageFilter.GaussianBlur(radius = 8))
octive2_5arr = np.asarray(octive2_5)
plt.imshow(octive2_5arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
dog2_1 = octive2arr - octive2_2arr
plt.imshow(dog2_1, cmap='gray', vmin=0, vmax=255)
plt.show()
dog2_2 = octive2_2arr - octive2_3arr
plt.imshow(dog2_2, cmap='gray', vmin=0, vmax=255)
plt.show()
dog2_3 = octive2_3arr - octive2_4arr
plt.imshow(dog2_3, cmap='gray', vmin=0, vmax=255)
plt.show()
dog2_4 = octive2_4arr - octive2_5arr
plt.imshow(dog2_4, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Third Octive

# %%
octive3 = octive1.resize((400, 267))
octive3arr = np.asarray(octive3)
plt.imshow(octive3arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive3_2 = octive3.filter(ImageFilter.GaussianBlur(radius = 5))
octive3_2arr = np.asarray(octive3_2)
plt.imshow(octive3_2arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive3_3 = octive3.filter(ImageFilter.GaussianBlur(radius = 6))
octive3_3arr = np.asarray(octive3_3)
plt.imshow(octive3_3arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive3_4 = octive3.filter(ImageFilter.GaussianBlur(radius = 7))
octive3_4arr = np.asarray(octive3_4)
plt.imshow(octive3_4arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive3_5 = octive3.filter(ImageFilter.GaussianBlur(radius = 8))
octive3_5arr = np.asarray(octive3_5)
plt.imshow(octive3_5arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
dog3_1 = octive3arr - octive3_2arr
plt.imshow(dog3_1, cmap='gray', vmin=0, vmax=255)
plt.show()
dog3_2 = octive3_2arr - octive3_3arr
plt.imshow(dog3_2, cmap='gray', vmin=0, vmax=255)
plt.show()
dog3_3 = octive3_3arr - octive3_4arr
plt.imshow(dog3_3, cmap='gray', vmin=0, vmax=255)
plt.show()
dog3_4 = octive3_4arr - octive3_5arr
plt.imshow(dog3_4, cmap='gray', vmin=0, vmax=255)
plt.show()

# %% [markdown]
# Fourth Octive

# %%
#image_file4 = image_file1.resize((200, 134))
octive4 = octive1.resize((200, 134))
octive4arr = np.asarray(octive4)
plt.imshow(octive4arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive4_2 = octive4.filter(ImageFilter.GaussianBlur(radius = 5))
octive4_2arr = np.asarray(octive4_2)
plt.imshow(octive4_2arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive4_3 = octive4.filter(ImageFilter.GaussianBlur(radius = 6))
octive4_3arr = np.asarray(octive4_3)
plt.imshow(octive4_3arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive4_4 = octive4.filter(ImageFilter.GaussianBlur(radius = 7))
octive4_4arr = np.asarray(octive4_4)
plt.imshow(octive4_4arr, cmap='gray', vmin=0, vmax=255)
plt.show()
octive4_5 = octive4.filter(ImageFilter.GaussianBlur(radius = 8))
octive4_5arr = np.asarray(octive4_5)
plt.imshow(octive4_5arr, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
dog4_1 = octive4arr - octive4_2arr
print(dog4_1.shape)
plt.imshow(dog4_1, cmap='gray', vmin=0, vmax=255)
plt.show()
dog4_2 = octive4_2arr - octive4_3arr
plt.imshow(dog4_2, cmap='gray', vmin=0, vmax=255)
plt.show()
dog4_3 = octive4_3arr - octive4_4arr
plt.imshow(dog4_3, cmap='gray', vmin=0, vmax=255)
plt.show()
dog4_4 = octive4_4arr - octive4_5arr
plt.imshow(dog4_4, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# (134, 200)

# %% [markdown]
# Local Max and Local Min

# %% [markdown]
# Octive 1

# %%
print(dog1_1.shape)
fig, (ax1, ax2) = plt.subplots(2)
Min1 = 0
Max1 = 0
Min2 = 0
Max2 = 0
for i in range (1,1066):
  for j in range (1,1599):
    interestpoint = dog1_2[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog1_1[i-1,j+c-1]:
          if interestpoint > dog1_1[i,j-1+c]:
            if interestpoint > dog1_1[i+1,j+c-1]:
              if interestpoint > dog1_3[i+1,j+c-1]:
                if interestpoint > dog1_3[i,j+c-1]:
                  if interestpoint > dog1_3[i+1,j+c-1]:
                    if interestpoint > dog1_2[i-1,j+c-1]:
                      if interestpoint > dog1_2[i+1,j+c-1]:
                        if interestpoint > dog1_2[i,j-1]:
                          if interestpoint > dog1_2[1,j+1]:
                            if interestpoint > dog1_2[1,j-1]:
                              Max1 = Max1 + 1
                              ax1.plot(j, i, 'b+')
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog1_1[i-1,j+c-1]:
            if interestpoint < dog1_1[i,j-1+c]:
              if interestpoint < dog1_1[i+1,j+c-1]:
                if interestpoint < dog1_3[i+1,j+c-1]:
                  if interestpoint < dog1_3[i,j+c-1]:
                    if interestpoint < dog1_3[i+1,j+c-1]:
                      if interestpoint < dog1_2[i-1,j+c-1]:
                        if interestpoint < dog1_2[i+1,j+c-1]:
                          if interestpoint < dog1_2[i,j-1]:
                            if interestpoint < dog1_2[1,j+1]:
                              if interestpoint < dog1_2[1,j-1]:
                                Min1 = Min1 + 1
for i in range (1,1066):
  for j in range (1,1599):
    interestpoint = dog1_3[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog1_2[i-1,j+c-1]:
          if interestpoint > dog1_2[i,j-1+c]:
            if interestpoint > dog1_2[i+1,j+c-1]:
              if interestpoint > dog1_4[i+1,j+c-1]:
                if interestpoint > dog1_4[i,j+c-1]:
                  if interestpoint > dog1_4[i+1,j+c-1]:
                    if interestpoint > dog1_3[i-1,j+c-1]:
                      if interestpoint > dog1_3[i+1,j+c-1]:
                        if interestpoint > dog1_3[i,j-1]:
                          if interestpoint > dog1_3[1,j+1]:
                            if interestpoint > dog1_3[1,j-1]:
                              ax2.plot(j, i, 'b+')
                              Max2 = Max2 + 1
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog1_2[i-1,j+c-1]:
            if interestpoint < dog1_2[i,j-1+c]:
              if interestpoint < dog1_2[i+1,j+c-1]:
                if interestpoint < dog1_4[i+1,j+c-1]:
                  if interestpoint < dog1_4[i,j+c-1]:
                    if interestpoint < dog1_4[i+1,j+c-1]:
                      if interestpoint < dog1_3[i-1,j+c-1]:
                        if interestpoint < dog1_3[i+1,j+c-1]:
                          if interestpoint < dog1_3[i,j-1]:
                            if interestpoint < dog1_3[1,j+1]:
                              if interestpoint < dog1_3[1,j-1]:
                                Min2 = Min2 + 1
print(Min1)
print(Max1)
print(Min2)
print(Max2)
# Out:
# (1067, 1600)
# 1962
# 24696
# 797
# 13959

# %% [markdown]
# Octive 2

# %%
print(dog2_1.shape)
fig, (ax1, ax2) = plt.subplots(2)
Min1_2 = 0
Max1_2 = 0
Min2_2 = 0
Max2_2 = 0
for i in range (1,533):
  for j in range (1,799):
    interestpoint = dog2_2[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog2_1[i-1,j+c-1]:
          if interestpoint > dog2_1[i,j-1+c]:
            if interestpoint > dog2_1[i+1,j+c-1]:
              if interestpoint > dog2_3[i+1,j+c-1]:
                if interestpoint > dog2_3[i,j+c-1]:
                  if interestpoint > dog2_3[i+1,j+c-1]:
                    if interestpoint > dog2_2[i-1,j+c-1]:
                      if interestpoint > dog2_2[i+1,j+c-1]:
                        if interestpoint > dog2_2[i,j-1]:
                          if interestpoint > dog2_2[1,j+1]:
                            if interestpoint > dog2_2[1,j-1]:
                              Max1_2 = Max1_2 + 1
                              ax1.plot(j, i, 'b+')
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog2_1[i-1,j+c-1]:
            if interestpoint < dog2_1[i,j-1+c]:
              if interestpoint < dog2_1[i+1,j+c-1]:
                if interestpoint < dog2_3[i+1,j+c-1]:
                  if interestpoint < dog2_3[i,j+c-1]:
                    if interestpoint < dog2_3[i+1,j+c-1]:
                      if interestpoint < dog2_2[i-1,j+c-1]:
                        if interestpoint < dog2_2[i+1,j+c-1]:
                          if interestpoint < dog2_2[i,j-1]:
                            if interestpoint < dog2_2[1,j+1]:
                              if interestpoint < dog2_2[1,j-1]:
                                Min1_2 = Min1_2 + 1
for i in range (1,533):
  for j in range (1,799):
    interestpoint = dog1_3[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog1_2[i-1,j+c-1]:
          if interestpoint > dog1_2[i,j-1+c]:
            if interestpoint > dog1_2[i+1,j+c-1]:
              if interestpoint > dog1_4[i+1,j+c-1]:
                if interestpoint > dog1_4[i,j+c-1]:
                  if interestpoint > dog1_4[i+1,j+c-1]:
                    if interestpoint > dog1_3[i-1,j+c-1]:
                      if interestpoint > dog1_3[i+1,j+c-1]:
                        if interestpoint > dog1_3[i,j-1]:
                          if interestpoint > dog1_3[1,j+1]:
                            if interestpoint > dog1_3[1,j-1]:
                              Max2_2 = Max2_2 + 1
                              ax2.plot(j, i, 'b+')
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog1_2[i-1,j+c-1]:
            if interestpoint < dog1_2[i,j-1+c]:
              if interestpoint < dog1_2[i+1,j+c-1]:
                if interestpoint < dog1_4[i+1,j+c-1]:
                  if interestpoint < dog1_4[i,j+c-1]:
                    if interestpoint < dog1_4[i+1,j+c-1]:
                      if interestpoint < dog1_3[i-1,j+c-1]:
                        if interestpoint < dog1_3[i+1,j+c-1]:
                          if interestpoint < dog1_3[i,j-1]:
                            if interestpoint < dog1_3[1,j+1]:
                              if interestpoint < dog1_3[1,j-1]:
                                Min2_2 = Min2_2 + 1
print(Min1_2)
print(Max1_2)
print(Min2_2)
print(Max2_2)
# Out:
# (534, 800)
# 502
# 6078
# 0
# 3133

# %% [markdown]
# Octive 3

# %%
print(dog3_1.shape)
fig, (ax1, ax2) = plt.subplots(2)
Min1_3 = 0
Max1_3 = 0
Min2_3 = 0
Max2_3 = 0
for i in range (1,266):
  for j in range (1,399):
    interestpoint = dog3_2[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog3_1[i-1,j+c-1]:
          if interestpoint > dog3_1[i,j-1+c]:
            if interestpoint > dog3_1[i+1,j+c-1]:
              if interestpoint > dog3_3[i+1,j+c-1]:
                if interestpoint > dog3_3[i,j+c-1]:
                  if interestpoint > dog3_3[i+1,j+c-1]:
                    if interestpoint > dog3_2[i-1,j+c-1]:
                      if interestpoint > dog3_2[i+1,j+c-1]:
                        if interestpoint > dog3_2[i,j-1]:
                          if interestpoint > dog3_2[1,j+1]:
                            if interestpoint > dog3_2[1,j-1]:
                              Max1_3 = Max1_3 + 1
                              ax1.plot(j, i, 'b+')
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog3_1[i-1,j+c-1]:
            if interestpoint < dog3_1[i,j-1+c]:
              if interestpoint < dog3_1[i+1,j+c-1]:
                if interestpoint < dog3_3[i+1,j+c-1]:
                  if interestpoint < dog3_3[i,j+c-1]:
                    if interestpoint < dog3_3[i+1,j+c-1]:
                      if interestpoint < dog3_2[i-1,j+c-1]:
                        if interestpoint < dog3_2[i+1,j+c-1]:
                          if interestpoint < dog3_2[i,j-1]:
                            if interestpoint < dog3_2[1,j+1]:
                              if interestpoint < dog3_2[1,j-1]:
                                Min1_3 = Min1_3 + 1
for i in range (1,266):
  for j in range (1,399):
    interestpoint = dog1_3[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog3_2[i-1,j+c-1]:
          if interestpoint > dog3_2[i,j-1+c]:
            if interestpoint > dog3_2[i+1,j+c-1]:
              if interestpoint > dog3_4[i+1,j+c-1]:
                if interestpoint > dog3_4[i,j+c-1]:
                  if interestpoint > dog3_4[i+1,j+c-1]:
                    if interestpoint > dog3_3[i-1,j+c-1]:
                      if interestpoint > dog3_3[i+1,j+c-1]:
                        if interestpoint > dog3_3[i,j-1]:
                          if interestpoint > dog3_3[1,j+1]:
                            if interestpoint > dog3_3[1,j-1]:
                              ax2.plot(j, i, 'b+')
                              Max2_3 = Max2_3 + 1
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog3_2[i-1,j+c-1]:
            if interestpoint < dog3_2[i,j-1+c]:
              if interestpoint < dog3_2[i+1,j+c-1]:
                if interestpoint < dog3_4[i+1,j+c-1]:
                  if interestpoint < dog3_4[i,j+c-1]:
                    if interestpoint < dog3_4[i+1,j+c-1]:
                      if interestpoint < dog3_3[i-1,j+c-1]:
                        if interestpoint < dog3_3[i+1,j+c-1]:
                          if interestpoint < dog3_3[i,j-1]:
                            if interestpoint < dog3_3[1,j+1]:
                              if interestpoint < dog3_3[1,j-1]:
                                Min2_3 = Min2_3 + 1
print(Min1_3)
print(Max1_3)
print(Min2_3)
print(Max2_3)
# Out:
# (267, 400)
# 176
# 1679
# 262
# 2684

# %% [markdown]
# Octive 4

# %%
print(dog4_1.shape)
plt.imshow(octive4arr, cmap='gray', vmin=0, vmax=255)
a = np.array([0])
Min1_4 = 0
Max1_4 = 0
Min2_4 = 0
Max2_4 = 0
for i in range (1,133):
  for j in range (1,199):
    interestpoint = dog4_2[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog4_1[i-1,j+c-1]:
          if interestpoint > dog4_1[i,j-1+c]:
            if interestpoint > dog4_1[i+1,j+c-1]:
              if interestpoint > dog4_3[i+1,j+c-1]:
                if interestpoint > dog4_3[i,j+c-1]:
                  if interestpoint > dog4_3[i+1,j+c-1]:
                    if interestpoint > dog4_2[i-1,j+c-1]:
                      if interestpoint > dog4_2[i+1,j+c-1]:
                        if interestpoint > dog4_2[i,j-1]:
                          if interestpoint > dog4_2[1,j+1]:
                            if interestpoint > dog4_2[1,j-1]:
                              Max1_4 = Max1_4 + 1
                              gx = abs(dog4_2[i+1,j] - dog4_2[i-1,j])
                              gy = abs(dog4_2[i,j+1] - dog4_2[i,j-1])
                              Magnitude = (gx * gx) + (gy * gy)
                              Magnitude = math.sqrt(Magnitude)
                              angle  = math.atan2(gy,gx)
                              np.append(a,[angle])
                              plt.plot(j, i, 'b+')
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog4_1[i-1,j+c-1]:
            if interestpoint < dog4_1[i,j-1+c]:
              if interestpoint < dog4_1[i+1,j+c-1]:
                if interestpoint < dog4_3[i+1,j+c-1]:
                  if interestpoint < dog4_3[i,j+c-1]:
                    if interestpoint < dog4_3[i+1,j+c-1]:
                      if interestpoint < dog4_2[i-1,j+c-1]:
                        if interestpoint < dog4_2[i+1,j+c-1]:
                          if interestpoint < dog4_2[i,j-1]:
                            if interestpoint < dog4_2[1,j+1]:
                              if interestpoint < dog4_2[1,j-1]:
                                Min1_4 = Min1_4 + 1
for i in range (1,133):
  for j in range (1,199):
    interestpoint = dog4_3[i,j]
    if interestpoint > 0:
      #comparision 1
      for c in range (1,3):
        if interestpoint > dog4_2[i-1,j+c-1]:
          if interestpoint > dog4_2[i,j-1+c]:
            if interestpoint > dog4_2[i+1,j+c-1]:
              if interestpoint > dog4_4[i+1,j+c-1]:
                if interestpoint > dog4_4[i,j+c-1]:
                  if interestpoint > dog4_4[i+1,j+c-1]:
                    if interestpoint > dog4_3[i-1,j+c-1]:
                      if interestpoint > dog4_3[i+1,j+c-1]:
                        if interestpoint > dog4_3[i,j-1]:
                          if interestpoint > dog4_3[1,j+1]:
                            if interestpoint > dog4_3[1,j-1]:
                              ax1.plot(i, j, 'b+')
                              gx = abs(dog4_3[i+1,j] - dog4_3[i-1,j])
                              gy = abs(dog4_3[i,j+1] - dog4_3[i,j-1])
                              Magnitude = (gx * gx) + (gy * gy)
                              Magnitude = math.sqrt(Magnitude)
                              angle  = math.atan2(gy,gx)
                              np.append(a,[angle])
                              Max2_4 = Max2_4 + 1
      if interestpoint > 0:
        #comparision 2
        for c in range (1,3):
          if interestpoint < dog4_2[i-1,j+c-1]:
            if interestpoint < dog4_2[i,j-1+c]:
              if interestpoint < dog4_2[i+1,j+c-1]:
                if interestpoint < dog4_4[i+1,j+c-1]:
                  if interestpoint < dog4_4[i,j+c-1]:
                    if interestpoint < dog4_4[i+1,j+c-1]:
                      if interestpoint < dog4_3[i-1,j+c-1]:
                        if interestpoint < dog4_3[i+1,j+c-1]:
                          if interestpoint < dog4_3[i,j-1]:
                            if interestpoint < dog4_3[1,j+1]:
                              if interestpoint < dog4_3[1,j-1]:
                                Min2_4 = Min2_4 + 1
print(Min1_4)
print(Max1_4)
print(Min2_4)
print(Max2_4)
print()
plt.show()
# Out:
# (134, 200)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: RuntimeWarning: overflow encountered in ubyte_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: overflow encountered in ubyte_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: overflow encountered in ubyte_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: RuntimeWarning: overflow encountered in ubyte_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:67: RuntimeWarning: overflow encountered in ubyte_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: RuntimeWarning: overflow encountered in ubyte_scalars
# 71
# 451
# 27
# 265
